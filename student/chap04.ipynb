# %% [markdown]
# Name: sarah Mohammed

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');
download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py
# Downloaded jupyturtle.py

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %%
def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

# %%
import math
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = angle / n
    polyline(n, length, step_angle)

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown, forward, make_turtle

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
# Answer 1:
def rectangle(wide, tall):
    for i in range(2):
        forward(wide)
        left(90)
        forward(tall)
        left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
from jupyturtle import make_turtle, forward, left

def rectangle(wide, tall):
    for i in range(2):
        forward(wide)
        left(90)
        forward(tall)
        left(90)


make_turtle()
rectangle(80, 40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="230.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="35.0" x2="150.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
# Answer 2:
def rhombus(side, angle):
    for i in range(2):
        forward(side)
        left(angle)
        forward(side)
        left(180 - angle)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="225.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.0" y1="31.7" x2="175.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="31.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
# Answer 3:
def parallelogram(width, height, angle):
    for i in range(2):
        forward(width)
        left(angle)
        forward(height)
        left(180 - angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(width=400)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="80.0" y1="75.0" x2="160.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="75.0" x2="160.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="35.0" x2="80.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="35.0" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="255.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.0" y1="31.7" x2="205.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.0" y1="31.7" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.0" y1="75.0" x2="340.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="340.0" y1="75.0" x2="365.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="365.0" y1="31.7" x2="285.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="285.0" y1="31.7" x2="260.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
# Answer 4:
from math import sin, radians

def triangle(n, size):
    angle = 360 / n
    side = 2 * size * sin(radians(angle / 2))

    forward(size)
    left(90 + angle / 2)
    forward(side)
    left(90 + angle / 2)
    forward(size)
    left(180 - angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
turtle = make_turtle(delay=0)
jump(-80)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="70.0" y1="75.0" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="82.4" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="82.4" y1="37.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="82.4" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="82.4" y1="37.0" x2="37.6" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="37.6" y1="51.5" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="37.6" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="37.6" y1="51.5" x2="37.6" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="37.6" y1="98.5" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="37.6" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="37.6" y1="98.5" x2="82.4" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="82.4" y1="113.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="82.4" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="82.4" y1="113.0" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="130.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="109.6" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="130.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="109.6" x2="170.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="109.6" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="170.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="109.6" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="270.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.0" y1="75.0" x2="254.9" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="43.7" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="254.9" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="43.7" x2="221.1" y2="36.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="36.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="221.1" y2="36.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="36.0" x2="194.0" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="57.6" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="194.0" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="57.6" x2="194.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="92.4" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="194.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="92.4" x2="221.1" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="114.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="221.1" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="114.0" x2="254.9" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="106.3" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="254.9" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="106.3" x2="270.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.0" y1="75.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,230.0,75.0) translate(230.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
# Answer 5:
def petal(radius, angle):
    arc(radius, angle)
    left(180 - angle)
    arc(radius, angle)
    left(180 - angle)

# %%
def flower(n, radius, angle):
    for i in range(n):
        petal(radius, angle)
        left(360 / n)

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
from jupyturtle import render

turtle = make_turtle(auto_render=False)

jump(-60)
n = 7
radius = 60
angle = 60
flower(n, radius, angle)

jump(120)
n = 9
radius = 40
angle = 85
flower(n, radius, angle)

render()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="90.0" y1="75.0" x2="92.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.1" y1="75.0" x2="94.2" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.2" y1="74.9" x2="96.3" y2="74.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.3" y1="74.8" x2="98.4" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.4" y1="74.6" x2="100.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.4" y1="74.3" x2="102.5" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.5" y1="73.9" x2="104.5" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.5" y1="73.5" x2="106.6" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.6" y1="73.0" x2="108.6" y2="72.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.6" y1="72.4" x2="110.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.6" y1="71.7" x2="112.6" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.6" y1="71.0" x2="114.5" y2="70.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.5" y1="70.2" x2="116.4" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.4" y1="69.4" x2="118.3" y2="68.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.3" y1="68.5" x2="120.1" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.1" y1="67.5" x2="122.0" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.0" y1="66.4" x2="123.7" y2="65.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="65.3" x2="125.5" y2="64.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.5" y1="64.2" x2="127.2" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="127.2" y1="62.9" x2="128.8" y2="61.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="61.6" x2="130.4" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.4" y1="60.3" x2="132.0" y2="58.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="58.9" x2="133.5" y2="57.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.5" y1="57.4" x2="134.9" y2="55.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.9" y1="55.9" x2="136.3" y2="54.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.3" y1="54.4" x2="137.7" y2="52.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.7" y1="52.8" x2="139.0" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.0" y1="51.1" x2="140.2" y2="49.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.2" y1="49.4" x2="141.4" y2="47.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="47.7" x2="142.5" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.5" y1="45.9" x2="140.4" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.4" y1="45.9" x2="138.3" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.3" y1="46.0" x2="136.2" y2="46.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.2" y1="46.1" x2="134.1" y2="46.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.1" y1="46.3" x2="132.0" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="46.6" x2="130.0" y2="47.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="47.0" x2="127.9" y2="47.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="127.9" y1="47.4" x2="125.9" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="125