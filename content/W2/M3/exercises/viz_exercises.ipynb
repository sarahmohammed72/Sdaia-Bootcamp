# %% [markdown]
# # Visualization Exercises

# %% [markdown]
# ### 1. Antibiotic use in children
#
# The bar plot and the pie chart below show the distribution of pre-existing medical conditions of children involved in a study on the optimal duration of antibiotic use in treatment of tracheitis, which is an upper respiratory infection.

# %% [markdown]
# ![](../../assets/viz_exercise_1.png)

# %% [markdown]
# a. What features are apparent in the bar plot but not in the pie chart?

# %% [markdown]
# In the bar plot, it is much easier to see the exact values (using the x-axis scale) and to rank the categories precisely. It also shows the smaller categories (like Gastrointestinal and Immunocompromised) much more clearly than the pie chart.

# %% [markdown]
# b. What features are apparent in the pie chart but not in the bar plot?

# %% [markdown]
# The pie chart clearly shows the part-to-whole relationship, making it easier to see what percentage of the total each condition represents. For example, you can instantly see that 'Prematurity' makes up roughly one-third of the entire circle.

# %% [markdown]
# c. Which graph would you prefer to use for displaying these categorical data?

# %% [markdown]
# I would prefer the bar plot. It is more effective for comparing the sizes of different categories, especially when they are numerous or similar in size. Bar plots are generally more accurate for the human eye to read and compare than angles in a pie chart.

# %% [markdown]
# ### 2. Black Lives Matter.
#
# A Washington Post-Schar School poll conducted in the United States in June 2020, among a random national sample of 1,006 adults, asked respondents whether they support or oppose protests following George Floyd’s killing that have taken place in cities across the US. The survey also collected information on the age of the respondents. (Washington Post 2020) The results are summarized in the stacked bar plot below.

# %% [markdown]
# ![](../../assets/viz_exercise_3.png)

# %% [markdown]
# a. Based on the stacked bar plot, do views on the protests and age appear to be associated? Explain your reasoning.

# %% [markdown]
# -Yes, there is an association. As age increases, the support for protests (blue sections) decreases, while the opposition (orange and pink sections) increases. For example, the 18-29 group shows the highest strong support, whereas the 65+ group shows the highest strong opposition.

# %% [markdown]
# b. Conjecture other possible variables that might explain the potential association between these two variables.

# %% [markdown]
# -Political Affiliation: Younger generations might lean toward different political ideologies compared to older generations.
#
# Media Consumption: Different age groups use different news sources (e.g., social media vs. traditional TV news), which can shape their opinions differently.
#
# Life Experiences: Older individuals might prioritize social stability or have different historical perspectives on protests compared to younger individuals

# %% [markdown]
# ### 3. Heart transplant data display.
#
# The Stanford University Heart Transplant Study was conducted to determine whether an experimental heart transplant program increased lifespan. Each patient entering the program was officially designated a heart transplant candidate, meaning that they were gravely ill and might benefit from a new heart. Patients were randomly assigned into treatment and control groups. Patients in the treatment group received a transplant, and those in the control group did not. The visualizations below display two different versions of the study results.9 (Turnbull, Brown, and Hu 1974)

# %% [markdown]
# ![](../../assets/viz_exercise_5.png)

# %% [markdown]
# a. Provide one aspect of the two group comparison that is easier to see from the stacked bar plot (left)?

# %% [markdown]
# It is easier to see the total sample size of each group. We can clearly see that the "treatment" group has more participants (about 70) than the "control" group (about 35).

# %% [markdown]
# b. Provide one aspect of the two group comparison that is easeir to see from the standardized bar plot (right)?

# %% [markdown]
# It is easier to compare the survival rate (proportion of alive vs. deceased) between the two groups. Because both bars are scaled to 1.00 (100%), we can instantly see that the "treatment" group has a much higher percentage of survivors (the blue section) compared to the "control" group.

# %% [markdown]
# c. For the Heart Transplant Study which of those aspects would be more important to display? That is, which bar plot would be better as a data visualization?

# %% [markdown]
# The standardized bar plot (right) would be better. In medical studies, the most important outcome is usually the effectiveness of the treatment (the survival rate), not just the number of people. Since the group sizes are different, comparing percentages (proportions) is the only fair way to show that the transplant actually helps patients live longer.

# %% [markdown]
# ### 4. Meat consumption and life expectancy.
#
# In data collected for You et al. (2022), total meat intake is associated with life expectancy (at birth) in 175 countries. Meat intake is measured in kg per capita per year (averaged over 2011 to 2013). The two ridge plots show an association between income and meat consumption (higher income countries tend to eat more meat) and an association between income and life expectancy (higher income countries have higher life expectancy).

# %% [markdown]
# ![](../../assets/viz_exercise_7.png)

# %% [markdown]
# a. Do the graphs above demonstrate that meat consumption and life expectancy are associated? That is, can you tell if countries with low meat consumption have low life expectancy? Explain.

# %% [markdown]
# Yes, they demonstrate an association. In the first plot, low-income countries have low meat consumption, while high-income countries eat more. In the second plot, low-income countries have lower life expectancy, while high-income countries live longer. Since both variables move in the same direction relative to income, they are associated with each other.

# %% [markdown]
# b. Let’s assume that you had a plot comparing meat consumption and life expectancy, and they do seem associated. Your friend says that the plot shows that high meat consumption leads to a longer life. You correctly say, no, we can’t tell if there is a causal realtionship because the relationship is confounded by income level. Explain what you mean.

# %% [markdown]
# I mean that correlation does not imply causation. Meat consumption and life expectancy are both linked to a third variable: Income. Higher income allows countries to afford better healthcare (which increases life expectancy) and more expensive food like meat. Therefore, it might be the wealth/healthcare that increases lifespan, not the meat itself. Income is the confounder that makes it look like meat is the cause.

# %% [markdown]
# c. How can you investigate the relationship between meat consumption and life expectancy in the presence of confounding variables (like income)?

# %% [markdown]
# We can use a technique called stratification or controlling for variables. This means we compare meat consumption and life expectancy within the same income group (e.g., comparing only high-income countries with each other). If the relationship still exists even when income is held constant, then we have stronger evidence, though we'd still need more rigorous testing to prove causation.
